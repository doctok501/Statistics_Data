# %%
with open('LaDodgers.csv') as f:
  print(f.readline())
# Out:
# Rk,Pos,Name,Age,G,PA,AB,R,H,2B,3B,HR,RBI,SB,CS,BB,SO,BA,OBP,SLG,OPS,OPS+,TB,GDP,HBP,SH,SF,IBB,Name-additional

# %%
import chardet
with open('LaDodgers.csv', 'rb') as f:
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
with open('LaDodgers.csv', 'rb') as f:
  print(f.readline())
  print(f.readline())
# Out:
# b'Rk,Pos,Name,Age,G,PA,AB,R,H,2B,3B,HR,RBI,SB,CS,BB,SO,BA,OBP,SLG,OPS,OPS+,TB,GDP,HBP,SH,SF,IBB,Name-additional\r\n'
# b'1,C,Will Smith,29,63,271,238,36,66,16,1,10,44,0,1,24,43,0.277,0.343,0.479,0.822,132,114,5,3,0,6,3,smithwi05\r\n'

# %%
import pandas as pd
df = pd.read_csv('LaDodgers.csv', encoding='utf-8')
print(df.head())
# Out:
#     Rk Pos                      Name   Age     G     PA     AB     R     H  \
# 0  1.0   C                Will Smith  29.0  63.0  271.0  238.0  36.0  66.0
# 1  2.0  1B          Freddie Freeman*  34.0  75.0  330.0  272.0  48.0  81.0
# 2  3.0  2B                Gavin Lux*  26.0  57.0  207.0  194.0  20.0  41.0
# 3  4.0  SS  Mookie Betts (10-day IL)  31.0  72.0  331.0  283.0  50.0  86.0
# 4  5.0  3B    Max Muncy* (10-day IL)  33.0  40.0  167.0  139.0  24.0  31.0
#
#      2B  ...    SLG    OPS   OPS+     TB  GDP  HBP   SH   SF  IBB  \
# 0  16.0  ...  0.479  0.822  132.0  114.0  5.0  3.0  0.0  6.0  3.0
# 1  20.0  ...  0.496  0.905  158.0  135.0  7.0  7.0  0.0  4.0  7.0
# 2   7.0  ...  0.284  0.544   56.0   55.0  5.0  0.0  0.0  0.0  0.0
# 3  16.0  ...  0.488  0.892  154.0  138.0  5.0  1.0  0.0  0.0  0.0
# 4   8.0  ...  0.475  0.798  125.0   66.0  1.0  2.0  0.0  5.0  2.0
#
#    Name-additional
# 0        smithwi05
# 1        freemfr01
# 2          luxga01
# 3        bettsmo01
# ...

# %%
df = pd.read_csv('LaDodgers.csv', encoding = 'utf-8', low_memory = False)
df.head()
# Out:
#     Rk Pos                      Name   Age     G     PA     AB     R     H  \
# 0  1.0   C                Will Smith  29.0  63.0  271.0  238.0  36.0  66.0
# 1  2.0  1B          Freddie Freeman*  34.0  75.0  330.0  272.0  48.0  81.0
# 2  3.0  2B                Gavin Lux*  26.0  57.0  207.0  194.0  20.0  41.0
# 3  4.0  SS  Mookie Betts (10-day IL)  31.0  72.0  331.0  283.0  50.0  86.0
# 4  5.0  3B    Max Muncy* (10-day IL)  33.0  40.0  167.0  139.0  24.0  31.0
#
#      2B  ...    SLG    OPS   OPS+     TB  GDP  HBP   SH   SF  IBB  \
# 0  16.0  ...  0.479  0.822  132.0  114.0  5.0  3.0  0.0  6.0  3.0
# 1  20.0  ...  0.496  0.905  158.0  135.0  7.0  7.0  0.0  4.0  7.0
# 2   7.0  ...  0.284  0.544   56.0   55.0  5.0  0.0  0.0  0.0  0.0
# 3  16.0  ...  0.488  0.892  154.0  138.0  5.0  1.0  0.0  0.0  0.0
# 4   8.0  ...  0.475  0.798  125.0   66.0  1.0  2.0  0.0  5.0  2.0
#
#    Name-additional
# 0        smithwi05
# 1        freemfr01
# 2          luxga01
# 3        bettsmo01
# ...

# %%
df.to_csv('batting.csv')

# %%
with open('batting.csv') as f:
  for i in range(3):
    print(f.readline(), end = '')
# Out:
# ,Rk,Pos,Name,Age,G,PA,AB,R,H,2B,3B,HR,RBI,SB,CS,BB,SO,BA,OBP,SLG,OPS,OPS+,TB,GDP,HBP,SH,SF,IBB,Name-additional
# 0,1.0,C,Will Smith,29.0,63.0,271.0,238.0,36.0,66.0,16.0,1.0,10.0,44.0,0.0,1.0,24.0,43.0,0.277,0.343,0.479,0.822,132.0,114.0,5.0,3.0,0.0,6.0,3.0,smithwi05
# 1,2.0,1B,Freddie Freeman*,34.0,75.0,330.0,272.0,48.0,81.0,20.0,2.0,10.0,43.0,3.0,2.0,47.0,52.0,0.298,0.409,0.496,0.905,158.0,135.0,7.0,7.0,0.0,4.0,7.0,freemfr01

# %%
ns_df = pd.read_csv('batting.csv', low_memory = False)
ns_df.head()
# Out:
#    Unnamed: 0   Rk Pos                      Name   Age     G     PA     AB  \
# 0           0  1.0   C                Will Smith  29.0  63.0  271.0  238.0
# 1           1  2.0  1B          Freddie Freeman*  34.0  75.0  330.0  272.0
# 2           2  3.0  2B                Gavin Lux*  26.0  57.0  207.0  194.0
# 3           3  4.0  SS  Mookie Betts (10-day IL)  31.0  72.0  331.0  283.0
# 4           4  5.0  3B    Max Muncy* (10-day IL)  33.0  40.0  167.0  139.0
#
#       R     H  ...    SLG    OPS   OPS+     TB  GDP  HBP   SH   SF  IBB  \
# 0  36.0  66.0  ...  0.479  0.822  132.0  114.0  5.0  3.0  0.0  6.0  3.0
# 1  48.0  81.0  ...  0.496  0.905  158.0  135.0  7.0  7.0  0.0  4.0  7.0
# 2  20.0  41.0  ...  0.284  0.544   56.0   55.0  5.0  0.0  0.0  0.0  0.0
# 3  50.0  86.0  ...  0.488  0.892  154.0  138.0  5.0  1.0  0.0  0.0  0.0
# 4  24.0  31.0  ...  0.475  0.798  125.0   66.0  1.0  2.0  0.0  5.0  2.0
#
#    Name-additional
# 0        smithwi05
# 1        freemfr01
# 2          luxga01
# ...

# %%
ns_df = pd.read_csv('batting.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#     Rk Pos                      Name   Age     G     PA     AB     R     H  \
# 0  1.0   C                Will Smith  29.0  63.0  271.0  238.0  36.0  66.0
# 1  2.0  1B          Freddie Freeman*  34.0  75.0  330.0  272.0  48.0  81.0
# 2  3.0  2B                Gavin Lux*  26.0  57.0  207.0  194.0  20.0  41.0
# 3  4.0  SS  Mookie Betts (10-day IL)  31.0  72.0  331.0  283.0  50.0  86.0
# 4  5.0  3B    Max Muncy* (10-day IL)  33.0  40.0  167.0  139.0  24.0  31.0
#
#      2B  ...    SLG    OPS   OPS+     TB  GDP  HBP   SH   SF  IBB  \
# 0  16.0  ...  0.479  0.822  132.0  114.0  5.0  3.0  0.0  6.0  3.0
# 1  20.0  ...  0.496  0.905  158.0  135.0  7.0  7.0  0.0  4.0  7.0
# 2   7.0  ...  0.284  0.544   56.0   55.0  5.0  0.0  0.0  0.0  0.0
# 3  16.0  ...  0.488  0.892  154.0  138.0  5.0  1.0  0.0  0.0  0.0
# 4   8.0  ...  0.475  0.798  125.0   66.0  1.0  2.0  0.0  5.0  2.0
#
#    Name-additional
# 0        smithwi05
# 1        freemfr01
# 2          luxga01
# 3        bettsmo01
# ...
